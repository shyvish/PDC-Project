# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import time
begin = time.time()
image = cv2.imread('waterfall_grey_1920_2520.raw.PNG')
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
kernel = (1/16) * np.array([[1, 2, 1],
                   [2, 4, 2],
                   [1, 2, 1]])
img = cv2.filter2D(image, -1, kernel)
fig, ax = plt.subplots(1,2,figsize=(20,10))
ax[0].imshow(image)
ax[1].imshow(img)
end = time.time()

# %%
end-begin
# Out:
# 41.23267839211
